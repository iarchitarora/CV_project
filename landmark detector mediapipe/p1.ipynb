# %%
import pickle
with open("face_ld.pkl","rb") as f:
    ld = pickle.load(f)

print(type(ld))
print(ld.landmark[0].x)
# Out:
# <class 'mediapipe.framework.formats.landmark_pb2.NormalizedLandmarkList'>
# 0.39956048130989075

# %%
import numpy as np

# %%
l1 = []
for i in range(len(ld.landmark)):
    l1.append([ld.landmark[i].x, ld.landmark[i].y])

# %%
arr = np.around(np.array([l1]) * 250)

# %%
print(arr)
# Out:
# [[[100. 175.]
#   [ 96. 160.]
#   [ 99. 164.]
#   [ 93. 143.]
#   [ 96. 155.]
#   [ 96. 148.]
#   [ 99. 132.]
#   [ 70. 131.]
#   [100. 121.]
#   [100. 115.]
#   [100.  92.]
#   [100. 177.]
#   [101. 180.]
#   [101. 181.]
#   [101. 181.]
#   [101. 184.]
#   [102. 188.]
#   [102. 191.]
#   [103. 191.]
#   [ 97. 162.]
#   [ 93. 162.]
#   [ 59. 113.]
#   [ 82. 134.]
#   [ 78. 134.]
#   [ 74. 134.]
#   [ 68. 132.]
#   [ 86. 133.]
#   [ 75. 122.]
#   [ 80. 123.]
#   [ 71. 123.]
#   [ 68. 125.]
#   [ 66. 135.]
#   [ 86. 196.]
#   [ 68. 129.]
#   [ 59. 132.]
#   [ 62. 132.]
#   [ 78. 153.]
#   [ 93. 174.]
#   [ 95. 180.]
#   [ 88. 176.]
#   [ 84. 177.]
#   [ 90. 180.]
#   [ 87. 180.]
#   [ 82. 181.]
#   [ 92. 160.]
#   [ 91. 155.]
#   [ 63. 122.]
#   [ 87. 142.]
#   [ 82. 157.]
#   [ 83. 154.]
#   [ 66. 152.]
#   [ 92. 149.]
#   [ 71. 117.]
#   [ 66. 119.]
#   [ 60. 105.]
#   [ 90. 121.]
#   [ 85. 125.]
#   [ 78. 177.]
#   [ 68. 171.]
#   [ 86. 160.]
#   [ 90. 161.]
#   [ 81. 180.]
# ...

# %%
with open("ld.pkl","wb") as f:
    pickle.dump(arr,f)

# %%
len(arr[:,:68,:])
# Out:
# 68
